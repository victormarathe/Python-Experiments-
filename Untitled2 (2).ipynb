# %%
#data type of the variable a:
a = 5
print(type(a))

# 1. Text Type:  str
j = str("welcome to Python")
print(j)
print(type(j)) 

#Numeric Types:  int, float, complex

# 1.int
s = 20
print(s)
print(type(s)) 

# 2.float
s = 20.5
print(s)
print(type(s)) 

# 3.complex
s = 2j
print(s)
print(type(s)) 

#Sequence Types:  list, tuple, range

# 1.list
s = ["lamborghini", "tesla", "tata", "Audi", "mahindra"]
print(s)
print(type(s)) 

# 2.tuple 
s = ("samsung", "vivo", "mi", "oneplus", "nokia")
print(s)
print(type(s)) 

# 3. range
s = range(7)
print(s)
print(type(s)) 

#Mapping Type:  dict

#dict
s = {"name" : "jay", "age" : 20}
print(s)
print(type(s)) 

#Set Types:  set, frozenset

# 1. set
p = {"boat", "jbl", "mivi", "sony"}
print(p)
print(type(p))

# 2. frozenset
p = frozenset({"sony", "boat", "jbl", "mivi"})
print(p)
print(type(p)) 

#Boolean Type:  bool
x = True

print(x)
print(type(x)) 

#Binary Types:  bytes, bytearray, memoryview

# 1. bytes
x = b"welcome"
print(x)
print(type(x)) 

# 2. bytearray
s = bytearray(4)
print(s)
print(type(s)) 

# 3.memoryview
s = memoryview(bytes(4))
print(s)
print(type(s))
# Out:
# <class 'int'>
# welcome to Python
# <class 'str'>
# 20
# <class 'int'>
# 20.5
# <class 'float'>
# 2j
# <class 'complex'>
# ['lamborghini', 'tesla', 'tata', 'Audi', 'mahindra']
# <class 'list'>
# ('samsung', 'vivo', 'mi', 'oneplus', 'nokia')
# <class 'tuple'>
# range(0, 7)
# <class 'range'>
# {'name': 'jay', 'age': 20}
# <class 'dict'>
# {'boat', 'sony', 'jbl', 'mivi'}
# <class 'set'>
# frozenset({'mivi', 'sony', 'jbl', 'boat'})
# <class 'frozenset'>
# True
# <class 'bool'>
# b'welcome'
# <class 'bytes'>
# bytearray(b'\x00\x00\x00\x00')
# <class 'bytearray'>
# <memory at 0x7f3c9b18bd50>
# <class 'memoryview'>
